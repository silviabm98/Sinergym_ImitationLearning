# %%
#########################################################################
## COMPROBAR GPU ASIGNADA EN COLABORATORY
#########################################################################
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

# %%
#########################################################################
## LIBRERIAS NECESARIAS
#########################################################################
import tensorflow as tf
import gymnasium as gym
import sinergym 
from sinergym.utils.wrappers import (LoggerWrapper, NormalizeAction,
                                     NormalizeObservation) 
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import numpy as np
import keras


# Librerias necesarias para BC
from stable_baselines3.common.evaluation import evaluate_policy

from imitation.algorithms import bc
from imitation.data.wrappers import RolloutInfoWrapper
from imitation.policies.serialize import load_policy
from imitation.util.util import make_vec_env
# Problema en rollout: es la función que define las transiciones expertas
import imitation.data.rollout as rollout 
from stable_baselines3.common.vec_env import DummyVecEnv

# %% [markdown]
# # 5ZONE

# %% [markdown]
# ## Creamos un vector de entornos

# %%
def _make_env():
     _env = gym.make("Eplus-5zone-hot-discrete-v1")
     _env = NormalizeObservation(_env)
     _env = LoggerWrapper(_env)
     return _env

venv = DummyVecEnv([_make_env for _ in range(1)])
# Out:
# #==============================================================================================#
# #==============================================================================================#

# %% [markdown]
# ## Creación de demostraciones expertas

# %%
env = gym.make("Eplus-5zone-hot-discrete-v1")
env = NormalizeObservation(env)
env = LoggerWrapper(env)
# Out:
# #==============================================================================================#
# #==============================================================================================#

# %%
# Función que devuekve la política experta 
def download_expert():
    print("Downloading a pretrained expert.")
    expert = load_policy(
        "ppo",
        path="model5zone.zip",
        venv=env,
    )
    return expert

# Función que devuelve trayectorias de la política experta 
def sample_expert_transitions():
    # Cargamos la política experta
    expert = download_expert()

    print("Sampling expert transitions.")

    # Generar trayectorias a partir de una política dada
    rollouts = rollout.rollout(
        expert,  # Política 
        venv,    # Entorno
        sample_until=rollout.make_sample_until(min_timesteps=None, min_episodes=1),  # EPISODES=1 asi que min_episodes=1
        rng=np.random.default_rng(),
        unwrap=False,
    )
    
    return rollout.flatten_trajectories(rollouts)

# %%
# Selección de una muestra de trayectorias de secuencias expertas
transitions = sample_expert_transitions()
# Out:
# Downloading a pretrained expert.
# Sampling expert transitions.
# #----------------------------------------------------------------------------------------------#
# #----------------------------------------------------------------------------------------------#
# /usr/local/lib/python3.10/dist-packages/gymnasium/spaces/box.py:240: UserWarning: WARN: Casting input x to numpy array.
#   gym.logger.warn("Casting input x to numpy array.")
# Progress: |****************************************************************************************************| 100%
# #----------------------------------------------------------------------------------------------#
# #----------------------------------------------------------------------------------------------#

# %% [markdown]
# ## 3. **Adversarial Inverse Reinforcement Learning (AIRL)**
#
# * Similar a GAIL
# * Se diferencia en que cubre casos donde la función de recompensa es ,as generalizable a cambios dinámicos del entorno

# %%
from imitation.rewards.reward_nets import BasicShapedRewardNet
from imitation.util.networks import RunningNorm
from imitation.algorithms.adversarial.airl import AIRL
from stable_baselines3 import PPO
from stable_baselines3.ppo import MlpPolicy

# %% [markdown]
# ## Experimento 1

# %%
SEED = 42

 
learner = PPO(
    env=venv,
    policy=MlpPolicy,
    batch_size=64,
    ent_coef=0.0,
    learning_rate=0.0005,
    gamma=0.95,
    clip_range=0.1,
    vf_coef=0.1,
    n_epochs=5,
    seed=SEED,
)

reward_net = BasicShapedRewardNet(
    observation_space=venv.observation_space,
    action_space=venv.action_space,
    normalize_input_layer=RunningNorm,
)

airl_trainer = AIRL(
    demonstrations=transitions,
    demo_batch_size=2048,
    gen_replay_buffer_capacity=512,
    n_disc_updates_per_round=16,
    venv=venv,
    gen_algo=learner,
    reward_net=reward_net,
)

# %%
venv.seed(SEED)

learner_rewards_before_training, _ = evaluate_policy(
    learner, venv, 5, return_episode_rewards=True,
)

airl_trainer.train(3504)  
venv.seed(SEED)

learner_rewards_after_training, _ = evaluate_policy(
    learner, venv, 5, return_episode_rewards=True,
)

# %%
print("mean reward after training:", np.mean(learner_rewards_after_training))
print("mean reward before training:", np.mean(learner_rewards_before_training))

# %% [markdown]
# ## Experimento 2

# %%
SEED = 42

 
learner = PPO(
    env=venv,
    policy=MlpPolicy,
    batch_size=64,
    ent_coef=0.0,
    learning_rate=0.0005,
    gamma=0.95,
    clip_range=0.1,
    vf_coef=0.1,
    n_epochs=5,
    seed=SEED,
)

reward_net = BasicShapedRewardNet(
    observation_space=venv.observation_space,
    action_space=venv.action_space,
    normalize_input_layer=RunningNorm,
)

airl_trainer = AIRL(
    demonstrations=transitions,
    demo_batch_size=2048,
    gen_replay_buffer_capacity=512,
    n_disc_updates_per_round=16,
    venv=venv,
    gen_algo=learner,
    reward_net=reward_net,
)

# %%
venv.seed(SEED)

learner_rewards_before_training, _ = evaluate_policy(
    learner, venv, 5, return_episode_rewards=True,
)

airl_trainer.train(7008)  
venv.seed(SEED)

learner_rewards_after_training, _ = evaluate_policy(
    learner, venv, 5, return_episode_rewards=True,
)

# %%
print("mean reward after training:", np.mean(learner_rewards_after_training))
print("mean reward before training:", np.mean(learner_rewards_before_training))

# %% [markdown]
# ## Experimento 3

# %%
SEED = 42

 
learner = PPO(
    env=venv,
    policy=MlpPolicy,
    batch_size=64,
    ent_coef=0.0,
    learning_rate=0.0005,
    gamma=0.95,
    clip_range=0.1,
    vf_coef=0.1,
    n_epochs=5,
    seed=SEED,
)

reward_net = BasicShapedRewardNet(
    observation_space=venv.observation_space,
    action_space=venv.action_space,
    normalize_input_layer=RunningNorm,
)

airl_trainer = AIRL(
    demonstrations=transitions,
    demo_batch_size=2048,
    gen_replay_buffer_capacity=512,
    n_disc_updates_per_round=16,
    venv=venv,
    gen_algo=learner,
    reward_net=reward_net,
)

# %%
venv.seed(SEED)

learner_rewards_before_training, _ = evaluate_policy(
    learner, venv, 5, return_episode_rewards=True,
)

airl_trainer.train(10512)  
venv.seed(SEED)

learner_rewards_after_training, _ = evaluate_policy(
    learner, venv, 5, return_episode_rewards=True,
)

# %%
print("mean reward after training:", np.mean(learner_rewards_after_training))
print("mean reward before training:", np.mean(learner_rewards_before_training))

# %% [markdown]
# ## Experimento 4

# %%
SEED = 42

 
learner = PPO(
    env=venv,
    policy=MlpPolicy,
    batch_size=64,
    ent_coef=0.0,
    learning_rate=0.0005,
    gamma=0.95,
    clip_range=0.1,
    vf_coef=0.1,
    n_epochs=5,
    seed=SEED,
)

reward_net = BasicShapedRewardNet(
    observation_space=venv.observation_space,
    action_space=venv.action_space,
    normalize_input_layer=RunningNorm,
)

airl_trainer = AIRL(
    demonstrations=transitions,
    demo_batch_size=2048,
    gen_replay_buffer_capacity=512,
    n_disc_updates_per_round=16,
    venv=venv,
    gen_algo=learner,
    reward_net=reward_net,
)

# %%
venv.seed(SEED)

learner_rewards_before_training, _ = evaluate_policy(
    learner, venv, 5, return_episode_rewards=True,
)

airl_trainer.train(14016)  
venv.seed(SEED)

learner_rewards_after_training, _ = evaluate_policy(
    learner, venv, 5, return_episode_rewards=True,
)

# %%
print("mean reward after training:", np.mean(learner_rewards_after_training))
print("mean reward before training:", np.mean(learner_rewards_before_training))

# %% [markdown]
# ## Experimento 5

# %%
SEED = 42

 
learner = PPO(
    env=venv,
    policy=MlpPolicy,
    batch_size=64,
    ent_coef=0.0,
    learning_rate=0.0005,
    gamma=0.95,
    clip_range=0.1,
    vf_coef=0.1,
    n_epochs=5,
    seed=SEED,
)

reward_net = BasicShapedRewardNet(
    observation_space=venv.observation_space,
    action_space=venv.action_space,
    normalize_input_layer=RunningNorm,
)

airl_trainer = AIRL(
    demonstrations=transitions,
    demo_batch_size=2048,
    gen_replay_buffer_capacity=512,
    n_disc_updates_per_round=16,
    venv=venv,
    gen_algo=learner,
    reward_net=reward_net,
)

# %%
venv.seed(SEED)

learner_rewards_before_training, _ = evaluate_policy(
    learner, venv, 5, return_episode_rewards=True,
)

airl_trainer.train(17520)  
venv.seed(SEED)

learner_rewards_after_training, _ = evaluate_policy(
    learner, venv, 5, return_episode_rewards=True,
)

# %%
print("mean reward after training:", np.mean(learner_rewards_after_training))
print("mean reward before training:", np.mean(learner_rewards_before_training))

# %% [markdown]
# ## Experimento 6

# %%
SEED = 42

 
learner = PPO(
    env=venv,
    policy=MlpPolicy,
    batch_size=64,
    ent_coef=0.0,
    learning_rate=0.0005,
    gamma=0.95,
    clip_range=0.1,
    vf_coef=0.1,
    n_epochs=5,
    seed=SEED,
)

reward_net = BasicShapedRewardNet(
    observation_space=venv.observation_space,
    action_space=venv.action_space,
    normalize_input_layer=RunningNorm,
)

airl_trainer = AIRL(
    demonstrations=transitions,
    demo_batch_size=2048,
    gen_replay_buffer_capacity=512,
    n_disc_updates_per_round=16,
    venv=venv,
    gen_algo=learner,
    reward_net=reward_net,
)

# %%
venv.seed(SEED)

learner_rewards_before_training, _ = evaluate_policy(
    learner, venv, 5, return_episode_rewards=True,
)

airl_trainer.train(21024)  
venv.seed(SEED)

learner_rewards_after_training, _ = evaluate_policy(
    learner, venv, 5, return_episode_rewards=True,
)

# %%
print("mean reward after training:", np.mean(learner_rewards_after_training))
print("mean reward before training:", np.mean(learner_rewards_before_training))

# %% [markdown]
# ## Experimento 7

# %%
SEED = 42

 
learner = PPO(
    env=venv,
    policy=MlpPolicy,
    batch_size=64,
    ent_coef=0.0,
    learning_rate=0.0005,
    gamma=0.95,
    clip_range=0.1,
    vf_coef=0.1,
    n_epochs=5,
    seed=SEED,
)

reward_net = BasicShapedRewardNet(
    observation_space=venv.observation_space,
    action_space=venv.action_space,
    normalize_input_layer=RunningNorm,
)

airl_trainer = AIRL(
    demonstrations=transitions,
    demo_batch_size=2048,
    gen_replay_buffer_capacity=512,
    n_disc_updates_per_round=16,
    venv=venv,
    gen_algo=learner,
    reward_net=reward_net,
)

# %%
venv.seed(SEED)

learner_rewards_before_training, _ = evaluate_policy(
    learner, venv, 5, return_episode_rewards=True,
)

airl_trainer.train(24528)  
venv.seed(SEED)

learner_rewards_after_training, _ = evaluate_policy(
    learner, venv, 5, return_episode_rewards=True,
)

# %%
print("mean reward after training:", np.mean(learner_rewards_after_training))
print("mean reward before training:", np.mean(learner_rewards_before_training))

# %% [markdown]
# ## Experimento 8

# %%
SEED = 42

 
learner = PPO(
    env=venv,
    policy=MlpPolicy,
    batch_size=64,
    ent_coef=0.0,
    learning_rate=0.0005,
    gamma=0.95,
    clip_range=0.1,
    vf_coef=0.1,
    n_epochs=5,
    seed=SEED,
)

reward_net = BasicShapedRewardNet(
    observation_space=venv.observation_space,
    action_space=venv.action_space,
    normalize_input_layer=RunningNorm,
)

airl_trainer = AIRL(
    demonstrations=transitions,
    demo_batch_size=2048,
    gen_replay_buffer_capacity=512,
    n_disc_updates_per_round=16,
    venv=venv,
    gen_algo=learner,
    reward_net=reward_net,
)

# %%
venv.seed(SEED)

learner_rewards_before_training, _ = evaluate_policy(
    learner, venv, 5, return_episode_rewards=True,
)

airl_trainer.train(28032)  
venv.seed(SEED)

learner_rewards_after_training, _ = evaluate_policy(
    learner, venv, 5, return_episode_rewards=True,
)

# %%
print("mean reward after training:", np.mean(learner_rewards_after_training))
print("mean reward before training:", np.mean(learner_rewards_before_training))

# %% [markdown]
# ## Experimento 9

# %%
SEED = 42

 
learner = PPO(
    env=venv,
    policy=MlpPolicy,
    batch_size=64,
    ent_coef=0.0,
    learning_rate=0.0005,
    gamma=0.95,
    clip_range=0.1,
    vf_coef=0.1,
    n_epochs=5,
    seed=SEED,
)

reward_net = BasicShapedRewardNet(
    observation_space=venv.observation_space,
    action_space=venv.action_space,
    normalize_input_layer=RunningNorm,
)

airl_trainer = AIRL(
    demonstrations=transitions,
    demo_batch_size=2048,
    gen_replay_buffer_capacity=512,
    n_disc_updates_per_round=16,
    venv=venv,
    gen_algo=learner,
    reward_net=reward_net,
)

# %%
venv.seed(SEED)

learner_rewards_before_training, _ = evaluate_policy(
    learner, venv, 5, return_episode_rewards=True,
)

airl_trainer.train(31536)  
venv.seed(SEED)

learner_rewards_after_training, _ = evaluate_policy(
    learner, venv, 5, return_episode_rewards=True,
)

# %%
print("mean reward after training:", np.mean(learner_rewards_after_training))
print("mean reward before training:", np.mean(learner_rewards_before_training))

# %% [markdown]
# ## Experimento 10

# %%
"""SEED = 42

 
learner = PPO(
    env=venv,
    policy=MlpPolicy,
    batch_size=64,
    ent_coef=0.0,
    learning_rate=0.0005,
    gamma=0.95,
    clip_range=0.1,
    vf_coef=0.1,
    n_epochs=5,
    seed=SEED,
)

reward_net = BasicShapedRewardNet(
    observation_space=venv.observation_space,
    action_space=venv.action_space,
    normalize_input_layer=RunningNorm,
)

airl_trainer = AIRL(
    demonstrations=transitions,
    demo_batch_size=2048,
    gen_replay_buffer_capacity=512,
    n_disc_updates_per_round=16,
    venv=venv,
    gen_algo=learner,
    reward_net=reward_net,
) """
# Out:
# Progress: |*--------------------------------------------------------------------------------------------------| 1%
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Progress: |****************************************************************************************************| 100%
# #----------------------------------------------------------------------------------------------#
# #----------------------------------------------------------------------------------------------#

# %%
""" venv.seed(SEED)

learner_rewards_before_training, _ = evaluate_policy(
    learner, venv, 5, return_episode_rewards=True,
)

airl_trainer.train(35038)  
venv.seed(SEED)

learner_rewards_after_training, _ = evaluate_policy(
    learner, venv, 5, return_episode_rewards=True,
) """
# Out:
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Progress: |****************************************************************************************************| 100%
# #----------------------------------------------------------------------------------------------#
# #----------------------------------------------------------------------------------------------#
# /usr/local/lib/python3.10/dist-packages/gymnasium/spaces/box.py:240: UserWarning: WARN: Casting input x to numpy array.
#   gym.logger.warn("Casting input x to numpy array.")
# Progress: |****************************************************************************************************| 100%
# #----------------------------------------------------------------------------------------------#
# #----------------------------------------------------------------------------------------------#
# /usr/local/lib/python3.10/dist-packages/gymnasium/spaces/box.py:240: UserWarning: WARN: Casting input x to numpy array.
#   gym.logger.warn("Casting input x to numpy array.")
# Progress: |****************************************************************************************************| 100%
# #----------------------------------------------------------------------------------------------#
# #----------------------------------------------------------------------------------------------#
# /usr/local/lib/python3.10/dist-packages/gymnasium/spaces/box.py:240: UserWarning: WARN: Casting input x to numpy array.
#   gym.logger.warn("Casting input x to numpy array.")
# Progress: |****************************************************************************************************| 100%
# #----------------------------------------------------------------------------------------------#
# #----------------------------------------------------------------------------------------------#
# /usr/local/lib/python3.10/dist-packages/gymnasium/spaces/box.py:240: UserWarning: WARN: Casting input x to numpy array.
#   gym.logger.warn("Casting input x to numpy array.")
# Progress: |****************************************************************************************************| 100%
# #----------------------------------------------------------------------------------------------#
# #----------------------------------------------------------------------------------------------#
# /usr/local/lib/python3.10/dist-packages/gymnasium/spaces/box.py:240: UserWarning: WARN: Casting input x to numpy array.
#   gym.logger.warn("Casting input x to numpy array.")
# Progress: |****************************************************************************************************| 100%
# #----------------------------------------------------------------------------------------------#
# #----------------------------------------------------------------------------------------------#
# round:   0%|          | 0/17 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Progress: |****************************************************************************************************| 100%
# #----------------------------------------------------------------------------------------------#
# #----------------------------------------------------------------------------------------------#
# /usr/local/lib/python3.10/dist-packages/gymnasium/spaces/box.py:240: UserWarning: WARN: Casting input x to numpy array.
#   gym.logger.warn("Casting input x to numpy array.")
# --------------------------------------------------------------------------------------------------------------| 6%
# | raw/                        |      |
# |    gen/time/fps             | 349  |
# |    gen/time/iterations      | 1    |
# |    gen/time/time_elapsed    | 5    |
# |    gen/time/total_timesteps | 2048 |
# --------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.354    |
# |    disc/disc_loss                   | 1.15     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.357    |
# |    disc/disc_loss                   | 1.14     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.36     |
# |    disc/disc_loss                   | 1.13     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.363    |
# |    disc/disc_loss                   | 1.12     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.367    |
# |    disc/disc_loss                   | 1.12     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.369    |
# |    disc/disc_loss                   | 1.11     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.373    |
# |    disc/disc_loss                   | 1.1      |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.375    |
# |    disc/disc_loss                   | 1.09     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.378    |
# |    disc/disc_loss                   | 1.09     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.382    |
# |    disc/disc_loss                   | 1.08     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.386    |
# |    disc/disc_loss                   | 1.07     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.388    |
# |    disc/disc_loss                   | 1.06     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.392    |
# |    disc/disc_loss                   | 1.05     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.395    |
# |    disc/disc_loss                   | 1.04     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.397    |
# |    disc/disc_loss                   | 1.04     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.4      |
# |    disc/disc_loss                   | 1.04     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.377    |
# |    disc/disc_loss                   | 1.09     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# |    gen/time/fps                     | 349      |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 5        |
# |    gen/time/total_timesteps         | 2.05e+03 |
# |    gen/train/approx_kl              | 0.00395  |
# |    gen/train/clip_fraction          | 0.164    |
# |    gen/train/clip_range             | 0.1      |
# |    gen/train/entropy_loss           | -2.3     |
# |    gen/train/explained_variance     | -0.178   |
# |    gen/train/learning_rate          | 0.0005   |
# |    gen/train/loss                   | 0.0136   |
# |    gen/train/n_updates              | 5        |
# |    gen/train/policy_gradient_loss   | -0.00907 |
# |    gen/train/value_loss             | 1.6      |
# --------------------------------------------------
# round:   6%|▌         | 1/17 [00:06<01:44,  6.50s/it]
# --------------------------------------------------------------------------------------------------------------| 12%
# | raw/                              |              |
# |    gen/time/fps                   | 729          |
# |    gen/time/iterations            | 1            |
# |    gen/time/time_elapsed          | 2            |
# |    gen/time/total_timesteps       | 4096         |
# |    gen/train/approx_kl            | 0.0039499034 |
# |    gen/train/clip_fraction        | 0.164        |
# |    gen/train/clip_range           | 0.1          |
# |    gen/train/entropy_loss         | -2.3         |
# |    gen/train/explained_variance   | -0.178       |
# |    gen/train/learning_rate        | 0.0005       |
# |    gen/train/loss                 | 0.0136       |
# |    gen/train/n_updates            | 5            |
# |    gen/train/policy_gradient_loss | -0.00907     |
# |    gen/train/value_loss           | 1.6          |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.402    |
# |    disc/disc_loss                   | 1.04     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.405    |
# |    disc/disc_loss                   | 1.03     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.407    |
# |    disc/disc_loss                   | 1.02     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.411    |
# |    disc/disc_loss                   | 1.01     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.415    |
# |    disc/disc_loss                   | 1        |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.417    |
# |    disc/disc_loss                   | 0.994    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.422    |
# |    disc/disc_loss                   | 0.985    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.426    |
# |    disc/disc_loss                   | 0.974    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.429    |
# |    disc/disc_loss                   | 0.965    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.433    |
# |    disc/disc_loss                   | 0.958    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.436    |
# |    disc/disc_loss                   | 0.948    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.44     |
# |    disc/disc_loss                   | 0.939    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.443    |
# |    disc/disc_loss                   | 0.928    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.445    |
# |    disc/disc_loss                   | 0.92     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.449    |
# |    disc/disc_loss                   | 0.909    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.452    |
# |    disc/disc_loss                   | 0.906    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.427    |
# |    disc/disc_loss                   | 0.97     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# |    gen/time/fps                     | 729      |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 2        |
# |    gen/time/total_timesteps         | 4.1e+03  |
# |    gen/train/approx_kl              | 0.00373  |
# |    gen/train/clip_fraction          | 0.163    |
# |    gen/train/clip_range             | 0.1      |
# |    gen/train/entropy_loss           | -2.3     |
# |    gen/train/explained_variance     | 0.545    |
# |    gen/train/learning_rate          | 0.0005   |
# |    gen/train/loss                   | 0.0291   |
# |    gen/train/n_updates              | 10       |
# |    gen/train/policy_gradient_loss   | -0.00983 |
# |    gen/train/value_loss             | 3.45     |
# --------------------------------------------------
# round:  12%|█▏        | 2/17 [00:09<01:10,  4.68s/it]
# --------------------------------------------------------------------------------------------------------------| 18%
# | raw/                              |              |
# |    gen/time/fps                   | 727          |
# |    gen/time/iterations            | 1            |
# |    gen/time/time_elapsed          | 2            |
# |    gen/time/total_timesteps       | 6144         |
# |    gen/train/approx_kl            | 0.0037344352 |
# |    gen/train/clip_fraction        | 0.163        |
# |    gen/train/clip_range           | 0.1          |
# |    gen/train/entropy_loss         | -2.3         |
# |    gen/train/explained_variance   | 0.545        |
# |    gen/train/learning_rate        | 0.0005       |
# |    gen/train/loss                 | 0.0291       |
# |    gen/train/n_updates            | 10           |
# |    gen/train/policy_gradient_loss | -0.00983     |
# |    gen/train/value_loss           | 3.45         |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.446    |
# |    disc/disc_loss                   | 0.93     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.45     |
# |    disc/disc_loss                   | 0.916    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.455    |
# |    disc/disc_loss                   | 0.907    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.455    |
# |    disc/disc_loss                   | 0.905    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.458    |
# |    disc/disc_loss                   | 0.897    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.461    |
# |    disc/disc_loss                   | 0.89     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.467    |
# |    disc/disc_loss                   | 0.88     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.469    |
# |    disc/disc_loss                   | 0.871    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.47     |
# |    disc/disc_loss                   | 0.869    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.474    |
# |    disc/disc_loss                   | 0.857    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.478    |
# |    disc/disc_loss                   | 0.851    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.483    |
# |    disc/disc_loss                   | 0.844    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.484    |
# |    disc/disc_loss                   | 0.837    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.488    |
# |    disc/disc_loss                   | 0.828    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.49     |
# |    disc/disc_loss                   | 0.818    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.493    |
# |    disc/disc_loss                   | 0.806    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.47     |
# |    disc/disc_loss                   | 0.869    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# |    gen/time/fps                     | 727      |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 2        |
# |    gen/time/total_timesteps         | 6.14e+03 |
# |    gen/train/approx_kl              | 0.00363  |
# |    gen/train/clip_fraction          | 0.172    |
# |    gen/train/clip_range             | 0.1      |
# |    gen/train/entropy_loss           | -2.29    |
# |    gen/train/explained_variance     | 0.434    |
# |    gen/train/learning_rate          | 0.0005   |
# |    gen/train/loss                   | 0.159    |
# |    gen/train/n_updates              | 15       |
# |    gen/train/policy_gradient_loss   | -0.0101  |
# |    gen/train/value_loss             | 4.99     |
# --------------------------------------------------
# round:  18%|█▊        | 3/17 [00:13<00:57,  4.12s/it]
# --------------------------------------------------------------------------------------------------------------| 23%
# | raw/                              |              |
# |    gen/time/fps                   | 725          |
# |    gen/time/iterations            | 1            |
# |    gen/time/time_elapsed          | 2            |
# |    gen/time/total_timesteps       | 8192         |
# |    gen/train/approx_kl            | 0.0036309871 |
# |    gen/train/clip_fraction        | 0.172        |
# |    gen/train/clip_range           | 0.1          |
# |    gen/train/entropy_loss         | -2.29        |
# |    gen/train/explained_variance   | 0.434        |
# |    gen/train/learning_rate        | 0.0005       |
# |    gen/train/loss                 | 0.159        |
# |    gen/train/n_updates            | 15           |
# |    gen/train/policy_gradient_loss | -0.0101      |
# |    gen/train/value_loss           | 4.99         |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.469    |
# |    disc/disc_loss                   | 0.908    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.475    |
# |    disc/disc_loss                   | 0.893    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.475    |
# |    disc/disc_loss                   | 0.893    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.479    |
# |    disc/disc_loss                   | 0.884    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.485    |
# |    disc/disc_loss                   | 0.875    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# ...
# | raw/                              |              |
# |    gen/time/fps                   | 722          |
# |    gen/time/iterations            | 1            |
# |    gen/time/time_elapsed          | 2            |
# |    gen/time/total_timesteps       | 34816        |
# |    gen/train/approx_kl            | 0.0036461586 |
# |    gen/train/clip_fraction        | 0.104        |
# |    gen/train/clip_range           | 0.1          |
# |    gen/train/entropy_loss         | -2.23        |
# |    gen/train/explained_variance   | 0.167        |
# |    gen/train/learning_rate        | 0.0005       |
# |    gen/train/loss                 | 0.398        |
# |    gen/train/n_updates            | 80           |
# |    gen/train/policy_gradient_loss | -0.00829     |
# |    gen/train/value_loss           | 11.9         |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.57     |
# |    disc/disc_acc_expert             | 0.724    |
# |    disc/disc_acc_gen                | 0.416    |
# |    disc/disc_entropy                | 0.624    |
# |    disc/disc_loss                   | 0.683    |
# |    disc/disc_proportion_expert_pred | 0.654    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 17       |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.572    |
# |    disc/disc_acc_expert             | 0.714    |
# |    disc/disc_acc_gen                | 0.43     |
# |    disc/disc_entropy                | 0.626    |
# |    disc/disc_loss                   | 0.678    |
# |    disc/disc_proportion_expert_pred | 0.642    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 17       |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.594    |
# |    disc/disc_acc_expert             | 0.721    |
# |    disc/disc_acc_gen                | 0.467    |
# |    disc/disc_entropy                | 0.625    |
# |    disc/disc_loss                   | 0.662    |
# |    disc/disc_proportion_expert_pred | 0.627    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 17       |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.615    |
# |    disc/disc_acc_expert             | 0.74     |
# |    disc/disc_acc_gen                | 0.489    |
# |    disc/disc_entropy                | 0.626    |
# |    disc/disc_loss                   | 0.653    |
# |    disc/disc_proportion_expert_pred | 0.625    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 17       |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.633    |
# |    disc/disc_acc_expert             | 0.755    |
# |    disc/disc_acc_gen                | 0.51     |
# |    disc/disc_entropy                | 0.623    |
# |    disc/disc_loss                   | 0.64     |
# |    disc/disc_proportion_expert_pred | 0.623    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 17       |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.598    |
# |    disc/disc_acc_expert             | 0.712    |
# |    disc/disc_acc_gen                | 0.483    |
# |    disc/disc_entropy                | 0.624    |
# |    disc/disc_loss                   | 0.656    |
# |    disc/disc_proportion_expert_pred | 0.615    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 17       |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.632    |
# |    disc/disc_acc_expert             | 0.728    |
# |    disc/disc_acc_gen                | 0.537    |
# |    disc/disc_entropy                | 0.621    |
# |    disc/disc_loss                   | 0.633    |
# |    disc/disc_proportion_expert_pred | 0.595    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 17       |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.618    |
# |    disc/disc_acc_expert             | 0.708    |
# |    disc/disc_acc_gen                | 0.527    |
# |    disc/disc_entropy                | 0.622    |
# |    disc/disc_loss                   | 0.641    |
# |    disc/disc_proportion_expert_pred | 0.591    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 17       |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.644    |
# |    disc/disc_acc_expert             | 0.726    |
# |    disc/disc_acc_gen                | 0.561    |
# |    disc/disc_entropy                | 0.621    |
# |    disc/disc_loss                   | 0.624    |
# |    disc/disc_proportion_expert_pred | 0.583    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 17       |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.631    |
# |    disc/disc_acc_expert             | 0.698    |
# |    disc/disc_acc_gen                | 0.564    |
# |    disc/disc_entropy                | 0.621    |
# |    disc/disc_loss                   | 0.625    |
# |    disc/disc_proportion_expert_pred | 0.567    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 17       |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.66     |
# |    disc/disc_acc_expert             | 0.724    |
# |    disc/disc_acc_gen                | 0.596    |
# |    disc/disc_entropy                | 0.62     |
# |    disc/disc_loss                   | 0.618    |
# |    disc/disc_proportion_expert_pred | 0.564    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 17       |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.651    |
# |    disc/disc_acc_expert             | 0.695    |
# |    disc/disc_acc_gen                | 0.607    |
# |    disc/disc_entropy                | 0.62     |
# |    disc/disc_loss                   | 0.614    |
# |    disc/disc_proportion_expert_pred | 0.544    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 17       |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.66     |
# |    disc/disc_acc_expert             | 0.693    |
# |    disc/disc_acc_gen                | 0.626    |
# |    disc/disc_entropy                | 0.618    |
# |    disc/disc_loss                   | 0.613    |
# |    disc/disc_proportion_expert_pred | 0.534    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 17       |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.671    |
# |    disc/disc_acc_expert             | 0.698    |
# |    disc/disc_acc_gen                | 0.645    |
# |    disc/disc_entropy                | 0.614    |
# |    disc/disc_loss                   | 0.602    |
# |    disc/disc_proportion_expert_pred | 0.527    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 17       |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.686    |
# |    disc/disc_acc_expert             | 0.713    |
# |    disc/disc_acc_gen                | 0.658    |
# |    disc/disc_entropy                | 0.615    |
# |    disc/disc_loss                   | 0.593    |
# |    disc/disc_proportion_expert_pred | 0.528    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 17       |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.686    |
# |    disc/disc_acc_expert             | 0.697    |
# |    disc/disc_acc_gen                | 0.675    |
# |    disc/disc_entropy                | 0.615    |
# |    disc/disc_loss                   | 0.588    |
# |    disc/disc_proportion_expert_pred | 0.511    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 17       |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.632    |
# |    disc/disc_acc_expert             | 0.716    |
# |    disc/disc_acc_gen                | 0.549    |
# |    disc/disc_entropy                | 0.621    |
# |    disc/disc_loss                   | 0.633    |
# |    disc/disc_proportion_expert_pred | 0.583    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 17       |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# |    gen/time/fps                     | 722      |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 2        |
# |    gen/time/total_timesteps         | 3.48e+04 |
# |    gen/train/approx_kl              | 0.00349  |
# |    gen/train/clip_fraction          | 0.13     |
# |    gen/train/clip_range             | 0.1      |
# |    gen/train/entropy_loss           | -2.21    |
# |    gen/train/explained_variance     | 0.743    |
# |    gen/train/learning_rate          | 0.0005   |
# |    gen/train/loss                   | 0.652    |
# |    gen/train/n_updates              | 85       |
# |    gen/train/policy_gradient_loss   | -0.00701 |
# |    gen/train/value_loss             | 10.5     |
# --------------------------------------------------
# round: 100%|██████████| 17/17 [01:02<00:00,  3.66s/it]
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Progress: |****************************************************************************************************| 100%
# #----------------------------------------------------------------------------------------------#
# #----------------------------------------------------------------------------------------------#
# /usr/local/lib/python3.10/dist-packages/gymnasium/spaces/box.py:240: UserWarning: WARN: Casting input x to numpy array.
#   gym.logger.warn("Casting input x to numpy array.")
# Progress: |****************************************************************************************************| 100%
# #----------------------------------------------------------------------------------------------#
# #----------------------------------------------------------------------------------------------#
# /usr/local/lib/python3.10/dist-packages/gymnasium/spaces/box.py:240: UserWarning: WARN: Casting input x to numpy array.
#   gym.logger.warn("Casting input x to numpy array.")
# Progress: |****************************************************************************************************| 100%
# #----------------------------------------------------------------------------------------------#
# #----------------------------------------------------------------------------------------------#
# /usr/local/lib/python3.10/dist-packages/gymnasium/spaces/box.py:240: UserWarning: WARN: Casting input x to numpy array.
#   gym.logger.warn("Casting input x to numpy array.")
# Progress: |****************************************************************************************************| 100%
# #----------------------------------------------------------------------------------------------#
# #----------------------------------------------------------------------------------------------#
# /usr/local/lib/python3.10/dist-packages/gymnasium/spaces/box.py:240: UserWarning: WARN: Casting input x to numpy array.
#   gym.logger.warn("Casting input x to numpy array.")
# Progress: |****************************************************************************************************| 100%
# #----------------------------------------------------------------------------------------------#
# #----------------------------------------------------------------------------------------------#
# /usr/local/lib/python3.10/dist-packages/gymnasium/spaces/box.py:240: UserWarning: WARN: Casting input x to numpy array.
#   gym.logger.warn("Casting input x to numpy array.")
# Progress: |****************************************************************************************************| 100%
# #----------------------------------------------------------------------------------------------#
# #----------------------------------------------------------------------------------------------#

# %%
"""print("mean reward after training:", np.mean(learner_rewards_after_training))
print("mean reward before training:", np.mean(learner_rewards_before_training))"""
# Out:
# mean reward after training: -21901.931846516578
# mean reward before training: -22185.937215596066
